# %%
import numpy as np
import pandas as pd
from plotnine import *
from plotnine.data import mpg

# %%
# %matplotlib inline

# %%
(ggplot(mpg)
+ aes(x='class')
+ geom_bar(size=20)
+ coord_flip()
+ labs(title='Number of Vehicles per Class',x='Vehicle Class',y='Number of Vehicles')
)
# Out:
# <ggplot: (-9223371880187778688)>

# %%
(ggplot(mpg)
+aes(x='class')
+geom_bar(size=20)
+coord_flip())
# Out:
# <ggplot: (-9223371880187777268)>

# %%
(ggplot(mpg)
+ aes(x='displ',y='hwy',color='class')
+ geom_point()
+ labs(title='Engine Displacement vs. Highway Miles per Gallon', x='Engine Displacement, in Litres', y='Highway Miles per Gallon')
)
# Out:
# <ggplot: (-9223371880187684596)>
