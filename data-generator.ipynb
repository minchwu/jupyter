# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
N = 361
t = np.linspace(0,2*np.pi,N)
f = np.exp(-t)*np.sin(t)
plt.plot(t,f)

# %%
f.resize((361,1))
np.savetxt('./data-test/f.txt',f)
np.savetxt('./data-test/t.txt',t)
