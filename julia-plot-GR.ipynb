# %%
using Plots
using SpecialFunctions
# Out:
# ArgumentError: Package SpecialFunctions not found in current path:
# - Run `import Pkg; Pkg.add("SpecialFunctions")` to install the SpecialFunctions package.
#
#
# Stacktrace:
#  [1] require(::Module, ::Symbol) at .\loading.jl:893
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
y = rand(20,1)
plot(y,linewidth=2,title="My Plot")

# %%
x = 0:0.01*pi:2*pi
y = sin.(x)
plot3d(x,y,y.^2)
# scatter(x,y)

# %%
x = collect(0:0.01:20)
fig1 = plot(x,SpecialFunctions.besselj.(0,x),SpecialFunctions.besselj.(1,x))

# %%
function fb(x)
    return SpecialFunctions.besselj.(0,x)
end
plot([t->SpecialFunctions.besselj.(1,t)],x)

# %%
x->x+1
# Out:
# #3 (generic function with 1 method)
