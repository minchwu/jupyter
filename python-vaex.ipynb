# %% [markdown]
# # Pandas VS. Vaex

# %% [markdown]
# ## 数据读取加速
# 从小规模数据(数学建模量级数据)读取速度来看，pandas读取CSV的速度要远高于Excel文件，因为Excel文件本质上是压缩包文件，读取时涉及更多的运算和解析，CSV本质为文本文件，读取简单

# %%
import numpy as np
import pandas as pd
import vaex as vx
import matplotlib.pyplot as plt

# %%
df1 = vx.read_csv("./data/data1.csv")
df2 = pd.read_csv("./data/data1.csv")

# %%
# with plt.style.context('science','no-latex'):
plt.figure(num=1, figsize=(16,12))
plt.plot(df2["Y轴加速度"][0:1000])
